# %% [markdown]
# # Week 7 Assignment
#
# _MkKinney 6.1_
#
# This week has been all about getting information off the internet both in structured data formats (CSV, JSON, etc) as well as HTML.  For these exercises, we're going to use two practical examples of fetching data from web pages to show how to use Pandas and BeautifulSoup to extract structured information from the web.
#
# ---
# ---

# %% [markdown]
# ### 33.1 Parsing a list in HTML
#
# Go to the Banner Health Price Transparency Page: https://www.bannerhealth.com/patients/billing/pricing-resources/hospital-price-transparency
#
# Notice that there is a list of hospitals and the city they are in.  We want to parse the underlying HTML to create a list of all the hospitals along with which city they're in.
#
# ```json
# [
#     ["Banner - University Medical Center Phoenix", "Arizona"],
#     ["Banner - University Medical Center South ", "Arizona"],
#     ...
# ]
# ```
#
# To examine the underlying HTML code, you can use Chrome, right-click, and choose **Inspect**.
#
# For reference, the documentation for BeautifulSoup is here: https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %% [markdown]
# In the cell below, create a function called **parse_banner(url)** that takes as it's one parameter the URL of the webpage to be parsed for links.  Make sure you include docstrings and a good test case using hte URL provided above.

# %%
from bs4 import BeautifulSoup
import requests

# Note that you'll need to fetch the data using the following syntax to include headers
# that make the web server think you're a real web browser.
headers = { "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 11_2_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36" }
response = requests.get('https://www.bannerhealth.com/patients/billing/pricing-resources/hospital-price-transparency', headers=headers)
s = BeautifulSoup(response.text, 'html.parser')
div = s.find_all('div', {"class":"col-md-8"})[0]
def parse_banner(url):
    for hospital_list in div.find_all('ul'):
        state = hospital_list.previous_sibling.previous_sibling.string
        for hospital in hospital_list.find_all('li'):
            print(state, hospital.text)

# %%
import doctest
doctest.run_docstring_examples(parse_banner, globals(), verbose=True)
# Out:
# Finding tests in NoName

# %%
banner = parse_banner('https://www.bannerhealth.com/patients/billing/pricing-resources/hospital-price-transparency')
assert len(banner)==38, 'Length of result should have been 38, but {} returned.'.format(len(banner))
assert banner[0][1]=='Arizona', 'Wrong data found in the first result item: {}'.format(banner[0])
# Out:
# Arizona Banner - University Medical Center Phoenix
# Arizona Banner - University Medical Center South
# Arizona Banner - University Medical Center Tucson
# Arizona Banner Baywood Medical Center
# Arizona Banner Behavioral Health Hospital
# Arizona Banner Boswell Medical Center
# Arizona Banner Casa Grande Medical Center
# Arizona Banner Del E. Webb Medical Center
# Arizona Banner Desert Medical Center/Cardon Children's Medical Center
# Arizona Banner Estrella Medical Center
# Arizona Banner Gateway Medical Center/Banner MD Anderson Cancer Center
# Arizona Banner Goldfield Medical Center
# Arizona Banner Heart Hospital
# Arizona Banner Ironwood Medical Center
# Arizona Banner Ocotillo Medical Center
# Arizona Banner Payson Medical Center
# Arizona Banner Rehabilitation Hospitals
# Arizona Banner Thunderbird Medical Center
# Arizona Page Hospital
# California Banner Lassen Medical Center
# Colorado Banner Fort Collins Medical Center
# Colorado McKee Medical Center
# Colorado North Colorado Medical Center
# Colorado Sterling Regional Medical Center
# Colorado East Morgan County Hospital
# Nebraska Ogallala Community Hospital
# Nevada Banner Churchill Community Hospital
# Wyoming Banner Wyoming Medical Center Central Campus
# Wyoming Banner Wyoming Medical Center East Campus
# Wyoming Community Hospital
# Wyoming Washakie Medical Center
# Wyoming Platte County Memorial Hospital
# State-Specific Regulations Arizona
# State-Specific Regulations California
# State-Specific Regulations Colorado
# State-Specific Regulations Nebraska
# State-Specific Regulations Nevada
# State-Specific Regulations Wyoming
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-b50f7d3d19d6> in <module>
#       1 banner = parse_banner('https://www.bannerhealth.com/patients/billing/pricing-resources/hospital-price-transparency')
# ----> 2 assert len(banner)==38, 'Length of result should have been 38, but {} returned.'.format(len(banner))
#       3 assert banner[0][1]=='Arizona', 'Wrong data found in the first result item: {}'.format(banner[0])
#
# TypeError: object of type 'NoneType' has no len()

# %% [markdown]
# ---
#
# ## 33.2 Using a REST API (from GitHub.com)
#
# Many websites provide something called a REST API to access information from their site programatically, rather than relying on HTML.  One example is GitHub.com, whose API allows you do to things like "list all the public repositories for a user."
#
# The documentation for GitHub.com's REST API can be found here: https://docs.github.com/en/rest/guides/getting-started-with-the-rest-api
#
# Create a function called **repo_summary(user)** that takes a GitHub.com user name as it's parameter and retrieves a list of all the repositories you can see for that user.  The specific documentation for the this kind of request can be found here: https://docs.github.com/en/rest/reference/repos#list-repositories-for-a-user. Make sure your function is well documented with a docstring and includes a simple test to verify that you get back 12 repositories when querying for the repositories for user **paulboal**.
#
# I've provided a related example to help you out.

# %%
# Example -- this example of code shows how to get basic information on the user paulboal
# For your solution, make sure you meet the requirements in the instructions above.

import requests

response = requests.get('https://api.github.com/users/paulboal')
data = response.json()

print('This information is about {}. His website is {}.'.format(data.get('login'), data.get('blog')))
# Out:
# This information is about paulboal. His website is www.amitechsolutions.com.

# %%
# Your code Here
def repo_summary(user):
    response = requests.get('https://api.github.com/users/'+user+'/repos')
    data = response.json()
    return data

# %%
import doctest
doctest.run_docstring_examples(repo_summary, globals(), verbose=True)
# Out:
# Finding tests in NoName

# %%
repos = repo_summary('paulboal')
assert len(repos)==12, 'Expecing 12, but {} were found'.format(len(repos))

# %% [markdown]
# ---
#
# ### 33.3 Find Something of Your Own
#
# Do some web searches and find an HTML page with some data that is interesting to something you're studying.  You can extract and parse that information using either BeautifulSoup or Pandas.  If you're using Pandas, then do something interesting to format and structure your data.  If you're using BeautifulSoup, you'll just need to do the work of parsing the data out of HTML -- that's hard enough!
#
# You don't need to build this as a function.  Just use notebook cells as I've done above.  You will be graded based on _style_.  Use variable names that make sense for your problem / solution. Cleanup anything you don't need before you submit your work.

# %%
# Your Code Here

# %%
import pandas as pd
tables = pd.read_html('https://www.arabidopsis.org/servlets/TairObject?id=28217&type=locus')
len(tables)
# Out:
# 15

# %%
for index,table in enumerate(tables):
    print("**************TABLE {}".format(index))
    print(table)
# Out:
# **************TABLE 0
#                   0                 1                        2   3
# 0  Locus: AT1G19340  Locus: AT1G19340  What's new on this page NaN
# **************TABLE 1
#                                                     0  \
# 0                          Representative Gene  Model
# 1                                     Gene Model Type
# 2                                        Other names:
# 3                                         Description
# 4                                    Map Detail Image
# 5                                         Annotations
# 6                                            Sequence
# 7                                            RNA Data
# 8                                                 NaN
# 9                                  One-channel Arrays
# 10                                                NaN
# 11                             Associated Transcripts
# 12                                    BAR eFP Browser
# 13                                         Chromosome
# 14                                       Protein Data
# 15                               Search Gene Families
# 16                                  Phylogenetic Tree
# 17  PANTHER 11 Plant Homologs  Showing 7 of 7 entries
# 18                                      Map Locations
# 19                                          Map Links
# 20  Polymorphism Showing 15  of 228 entries (see all)
# 21      Germplasm Showing 15  of 22 entries (see all)
# 22                    Clones (showing 5 of 5 entries)
# 23                                      External Link
# 24  Community Comments (shows only the most recent...
# 25                                                NaN
# 26                                                NaN
# 27                                 Date last modified
# 28                                     TAIR Accession
#
#                                                     1  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  Community Comments (shows only the most recent...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
#
#                                                     2
# 0                                         AT1G19340.1
# 1                                      protein_coding
# 2                                                 NaN
# 3   Methyltransferase MT-A70 family protein;(sourc...
# 4            Center on AT1G19340  |  Full-screen view
# 5   category  relationship  type keyword GO Biolog...
# 6   full length CDS  full length genomic  full len...
# 7                                                 NaN
# 8                                                 NaN
# 9   array elementname avg. signalintensity  (std. ...
# 10                                                NaN
# 11   type  number associated  EST  ( 8 )  cDNA  ( 3 )
# 12            Data Source  Powered by BAR Webservices
# 13                                                  1
# 14  name  length(aa)  molecular weight  isoelectri...
# 15  EnsemblPlants  PhyloGenes  InParanoid Ortholog...
# 16                                                NaN
# 17  Organism  UniProt Accession  Gene  Functional ...
# 18  chrom  map  map type coordinates  orientation ...
# 19         MapViewer Sequence Viewer GBrowse  JBrowse
# 20  name type polymorphism site  gene names  allel...
# 21  name  polymorphisms  background  stock name  S...
# 22  Clone Name  Aliases  GenBankAccession  VectorT...
# 23  Epigenomics  Danforth Center Small RNA/PARE/Me...
# 24  Community Comments (shows only the most recent...
# 25                                                NaN
# 26                                                NaN
# 27                                         2013-02-11
# 28                                      Locus:2016462
# **************TABLE 2
# Empty DataFrame
# Columns: [AT1G19340.1]
# Index: []
# **************TABLE 3
#                           category         Unnamed: 1  \
# 0            GO Biological Process                NaN
# 1            GO Cellular Component                NaN
# 2            GO Cellular Component                NaN
# 3            GO Molecular Function                NaN
# 4  Growth and Developmental Stages                NaN
# 5                  Plant structure                NaN
# 6                Annotation Detail  Annotation Detail
#
#            relationship  type         Unnamed: 3  \
# 0  acts upstream of or within                NaN
# 1                is active in                NaN
# 2                  located in                NaN
# 3                     enables                NaN
# 4            expressed during                NaN
# 5                expressed in                NaN
# 6           Annotation Detail  Annotation Detail
#
#                                              keyword
# 0  embryo development, methylation, response to o...
# 1                                            nucleus
# 2                                            nucleus
# 3   methyltransferase activity, nucleic acid binding
# 4  flowering stage, petal differentiation and exp...
# 5  collective leaf structure, flower, flower pedi...
# 6                                  Annotation Detail
# **************TABLE 4
#   array elementname avg. signalintensity  (std. error)  \
# 0         260669_AT                    44.308  (0.554)
#
#   avg. signalpercentile  (std. error)
# 0                     37.750  (0.250)
# **************TABLE 5
#    type number associated
# 0   EST             ( 8 )
# 1  cDNA             ( 3 )
# **************TABLE 6
#           name  Unnamed: 1  length(aa)  Unnamed: 3  molecular weight  \
# 0  AT1G19340.1         NaN       414.0         NaN           47892.8
# 1          NaN         NaN         NaN         NaN               NaN
# 2          NaN         NaN         NaN         NaN               NaN
#
#    Unnamed: 5  isoelectric point  Unnamed: 7  \
# 0         NaN               6.51         NaN
# 1         NaN                NaN         NaN
# 2         NaN                NaN         NaN
#
#                         INTERPRO domains
# 0  DNA_methylase_N6_adenine_CS:IPR002052
# 1                  MT-A70-like:IPR007757
# 2         SAM-dependent_MTases:IPR029063
# **************TABLE 7
#                                  0   1           2
# 0                    EnsemblPlants NaN  PhyloGenes
# 1       InParanoid Ortholog Groups NaN   PhylomeDB
# 2                          PANTHER NaN   Phytozome
# 3  PGDD duplications and orthologs NaN       PLAZA
# **************TABLE 8
#     0   1
# 0 NaN NaN
# **************TABLE 9
#                                        Organism UniProt Accession  \
# 0  Brachypodium distachyon (Purple false brome)            I1H8J3
# 1                         Glycine max (Soybean)            K7M5H2
# 2                         Glycine max (Soybean)            K7MNU4
# 3                  Physcomitrella patens (Moss)            A9RWK4
# 4        Populus trichocarpa (Black Cottonwood)            U5FSB1
# 5                 Solanum lycopersicum (Tomato)            K4BV74
# 6                        Vitis vinifera (Grape)            F6H041
#
#                 Gene Functional Information
# 0       BRADI1G71260      Search in QuickGO
# 1      GLYMA14G08331      Search in QuickGO
# 2      GLYMA17G36721      Search in QuickGO
# 3  PHYPADRAFT_206270      Search in QuickGO
# 4  POPTR_0014S04090G      Search in QuickGO
# 5   SOLYC04G079950.2      Search in QuickGO
# 6  VIT_18S0001G11990      Search in QuickGO
# **************TABLE 10
#    chrom  map      map type             coordinates orientation  attrib  \
# 0      1  AGI  nuc_sequence  6684467  - 6687116  bp     forward     NaN
#
#   Unnamed: 6
# 0    details
# **************TABLE 11
#            name  Unnamed: 1       type  Unnamed: 3 polymorphism site  \
# 0   FLAG_123E08         NaN  insertion         NaN          promoter
# 1   GABI_405B07         NaN  insertion         NaN             3'UTR
# 2   GABI_456D02         NaN  insertion         NaN             3'UTR
# 3   GABI_551D01         NaN  insertion         NaN            intron
# 4   GABI_551F08         NaN  insertion         NaN            intron
# 5   GABI_552F07         NaN  insertion         NaN            intron
# 6   GABI_552F12         NaN  insertion         NaN            intron
# 7   GABI_554B10         NaN  insertion         NaN            intron
# 8   GABI_556A07         NaN  insertion         NaN            intron
# 9   GABI_556A09         NaN  insertion         NaN            intron
# 10  GABI_556C03         NaN  insertion         NaN            intron
# 11  GABI_556C06         NaN  insertion         NaN            intron
# 12  GABI_556D04         NaN  insertion         NaN            intron
# 13  GABI_556E05         NaN  insertion         NaN            intron
# 14  GABI_556E11         NaN  insertion         NaN            intron
#
#     Unnamed: 5   gene names  Unnamed: 7 allele type
# 0          NaN  AT1G19340.1         NaN     unknown
# 1          NaN  AT1G19340.1         NaN     unknown
# 2          NaN  AT1G19340.1         NaN     unknown
# 3          NaN  AT1G19340.1         NaN     unknown
# 4          NaN  AT1G19340.1         NaN     unknown
# 5          NaN  AT1G19340.1         NaN     unknown
# 6          NaN  AT1G19340.1         NaN     unknown
# 7          NaN  AT1G19340.1         NaN     unknown
# 8          NaN  AT1G19340.1         NaN     unknown
# 9          NaN  AT1G19340.1         NaN     unknown
# 10         NaN  AT1G19340.1         NaN     unknown
# 11         NaN  AT1G19340.1         NaN     unknown
# 12         NaN  AT1G19340.1         NaN     unknown
# 13         NaN  AT1G19340.1         NaN     unknown
# 14         NaN  AT1G19340.1         NaN     unknown
# **************TABLE 12
#                 name        Unnamed: 1  \
# 0        SALK_070229               NaN
# 1             images            images
# 2     None available    None available
# 3         phenotypes        phenotypes
# 4     None available    None available
# ..               ...               ...
# 85            images            images
# 86    None available    None available
# 87        phenotypes        phenotypes
# 88    None available    None available
# 89  (European Users)  (European Users)
#
#                                         polymorphisms        Unnamed: 3  \
# 0   SALK_070229.55.50.x; SALKseq_070229.0; SALKseq...               NaN
# 1                                              images            images
# 2                                      None available    None available
# 3                                          phenotypes        phenotypes
# 4                                      None available    None available
# ..                                                ...               ...
# 85                                             images            images
# 86                                     None available    None available
# 87                                         phenotypes        phenotypes
# 88                                     None available    None available
# 89                                   (European Users)  (European Users)
#
#           background        Unnamed: 5        stock name
# 0                NaN               NaN       SALK_070229
# 1             images            images            images
# 2     None available    None available    None available
# 3         phenotypes        phenotypes        phenotypes
# 4     None available    None available    None available
# ..               ...               ...               ...
# 85            images            images            images
# 86    None available    None available    None available
# 87        phenotypes        phenotypes        phenotypes
# 88    None available    None available    None available
# 89  (European Users)  (European Users)  (European Users)
#
# [90 rows x 7 columns]
# **************TABLE 13
#       Clone Name   Aliases GenBankAccession VectorType Stock Number
# 0   CATMA1A18370       NaN              NaN    plasmid     CD253645
# 1  RAFL17-42-J02       NaN         AK117739    plasmid          NaN
# 2       21403662  122669.0         AY084952        NaN          NaN
# 3       BT012063       NaN         BT012063        NaN          NaN
# 4  CATMA1A18370D       NaN              NaN    plasmid          NaN
# 5            NaN       NaN              NaN        NaN          NaN
# **************TABLE 14
#                                                     0
# 0                                         Epigenomics
# 1          Danforth Center Small RNA/PARE/Methylation
# 2                             Expression/Localization
# 3                                              AraQTL
# 4                                            ATTED-II
# 5                                         eFP Browser
# 6                  Eukaryotic Promoter Database (EPD)
# 7                         Genevisible Expression Data
# 8   The Subcellular Location of Proteins in Arabid...
# 9              TraVA:Transcription Variation Analysis
# 10  Gene Families  Links moved to Gene Families ba...
# 11                                           Genomics
# 12                                            AceView
# 13                                            Gramene
# 14                                               MIPS
# 15                                   NCBI-Entrez Gene
# 16                                   Thalemine at BAR
# 17                                       Interactions
# 18                                            BioGRID
# 19                                              Other
# 20                                         BAR ePlant
# 21                           BAR ePlant Molecule View
# 22                     Polymorphisms/Alleles/Variants
# 23                                    Salk SNP Viewer
# 24                                      T-DNA Express
# 25                                         Proteomics
# 26               AlphaFold Protein Structure Database
# 27                                         AtProteome
# 28  Functional Analysis Tools for Post-Translation...
# 29                            Plant Proteome Database
# 30                                   Plant PTM Viewer
# 31                                           Reagents
# 32                                Agrisera (antibody)
# 33                                 PhytoAB (antibody)
# 34       RIKEN BioResource Research Center (Seed/DNA)

# %%
print(tables[1])
# Out:
#                                                     0  \
# 0                          Representative Gene  Model
# 1                                     Gene Model Type
# 2                                        Other names:
# 3                                         Description
# 4                                    Map Detail Image
# 5                                         Annotations
# 6                                            Sequence
# 7                                            RNA Data
# 8                                                 NaN
# 9                                  One-channel Arrays
# 10                                                NaN
# 11                             Associated Transcripts
# 12                                    BAR eFP Browser
# 13                                         Chromosome
# 14                                       Protein Data
# 15                               Search Gene Families
# 16                                  Phylogenetic Tree
# 17  PANTHER 11 Plant Homologs  Showing 7 of 7 entries
# 18                                      Map Locations
# 19                                          Map Links
# 20  Polymorphism Showing 15  of 228 entries (see all)
# 21      Germplasm Showing 15  of 22 entries (see all)
# 22                    Clones (showing 5 of 5 entries)
# 23                                      External Link
# 24  Community Comments (shows only the most recent...
# 25                                                NaN
# 26                                                NaN
# 27                                 Date last modified
# 28                                     TAIR Accession
#
#                                                     1  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  Community Comments (shows only the most recent...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
#
#                                                     2
# 0                                         AT1G19340.1
# 1                                      protein_coding
# 2                                                 NaN
# 3   Methyltransferase MT-A70 family protein;(sourc...
# 4            Center on AT1G19340  |  Full-screen view
# 5   category  relationship  type keyword GO Biolog...
# 6   full length CDS  full length genomic  full len...
# 7                                                 NaN
# 8                                                 NaN
# 9   array elementname avg. signalintensity  (std. ...
# 10                                                NaN
# 11   type  number associated  EST  ( 8 )  cDNA  ( 3 )
# 12            Data Source  Powered by BAR Webservices
# 13                                                  1
# 14  name  length(aa)  molecular weight  isoelectri...
# 15  EnsemblPlants  PhyloGenes  InParanoid Ortholog...
# 16                                                NaN
# 17  Organism  UniProt Accession  Gene  Functional ...
# 18  chrom  map  map type coordinates  orientation ...
# 19         MapViewer Sequence Viewer GBrowse  JBrowse
# 20  name type polymorphism site  gene names  allel...
# 21  name  polymorphisms  background  stock name  S...
# 22  Clone Name  Aliases  GenBankAccession  VectorT...
# 23  Epigenomics  Danforth Center Small RNA/PARE/Me...
# 24  Community Comments (shows only the most recent...
# 25                                                NaN
# 26                                                NaN
# 27                                         2013-02-11
# 28                                      Locus:2016462

# %% [markdown]
# ---
#
# ## Check your work above
#
# If you didn't get them all correct, take a few minutes to think through those that aren't correct.
#
#
# ## Submitting Your Work
#
# In order to submit your work, you'll need to use the `git` command line program to **add** your homework file (this file) to your local repository, **commit** your changes to your local repository, and then **push** those changes up to github.com.  From there, I'll be able to **pull** the changes down and do my grading.  I'll provide some feedback, **commit** and **push** my comments back to you.  Next week, I'll show you how to **pull** down my comments.
#
# To run through everything one last time and submit your work:
# 1. Use the `Kernel` -> `Restart Kernel and Run All Cells` menu option to run everything from top to bottom and stop here.
# 2. Follow the instruction on the prompt below to either ssave and submit your work, or continue working.
#
# If anything fails along the way with this submission part of the process, let me know.  I'll help you troubleshoort.

# %% [markdown]
# ---

# %%
a=input('''
Are you ready to submit your work?
1. Click the Save icon (or do Ctrl-S / Cmd-S)
2. Type "yes" or "no" below
3. Press Enter

''')

if a=='yes':
    # !git add week07_assignment_2.ipynb
    # !git commit -a -m "Submitting the week 7 programming exercises"
    # !git push
else:
    print('''
    
OK. We can wait.
''')
# Out:
# Are you ready to submit your work?
# 1. Click the Save icon (or do Ctrl-S / Cmd-S)
# 2. Type "yes" or "no" below
# 3. Press Enter
#
#  yes
# [main d88bc5b] Submitting the week 7 programming exercises
#  2 files changed, 297 insertions(+), 8 deletions(-)
#  create mode 100644 week07/week07_assignment_2.ipynb
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 3.66 KiB | 3.66 MiB/s, done.
# Total 5 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To github.com:paulboal/hds5210-2022.git
#    fc2200c..d88bc5b  main -> main
